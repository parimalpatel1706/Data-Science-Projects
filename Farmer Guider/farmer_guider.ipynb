# %%
import pandas as pd
import joblib

# %%
df=pd.read_csv(r"C:\Users\PARIMAL\OneDrive\Desktop\Data Science Internship\Projects\Farmer Guider\cleaned_farmer_datasets.csv")

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536      0
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537      0
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248      0
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034      0
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340      0
# ...   ...  ..  ..          ...        ...       ...         ...    ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507     21
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610     21
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839     21
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293     21
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041     21
#
# [2200 rows x 8 columns]

# %%
x = df.drop('label', axis=1)
y = df['label']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
print("this is train score:-",rfc.score(x_train,y_train))
print("this is test score:-",rfc.score(x_test,y_test))
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# this is train score:- 1.0
# this is test score:- 0.9931818181818182
# RandomForestClassifier()

# %%
joblib.dump(model, 'model_compressed.lb', compress=3)
# Out:
# ['model_compressed.lb']

# %%
prdct1 = rfc.predict(x_test)
print("Predictions:", prdct1)
